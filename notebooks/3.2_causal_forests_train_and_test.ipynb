# %%
library(grf)
library(tidyverse)
library(ggplot2)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1       ✔ purrr   0.3.2
# ✔ tibble  2.1.1       ✔ dplyr   0.8.0.1
# ✔ tidyr   0.8.3       ✔ stringr 1.4.0
# ✔ readr   1.3.1       ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# ### Causal Forests

# %%
fold = 'Fold3'

# %%
feature_column_names = read_csv(paste0('../build/simulation/', fold, '/examination_fc_names.csv'), col_types='ic')
# Out:
# Warning message:
# “Missing column names filled in: 'X1' [1]”

# %%
feature_column_names
# Out:
#    X1 feature_column_names
# 1  0  13
# 2  1  38
# 3  2  53
# 4  3  63
# 5  4  64
# 6  5  88
# 7  6  107
# 8  7  126
# 9  8  129
# 10 9  133

# %%
feature_col = feature_column_names$feature_column_names

# %%
propensity_test_features = read_csv(paste0('../build/simulation/', fold, '/examination_test.csv'))
# Out:
# Parsed with column specification:
# cols(
#   qid = col_double(),
#   y = col_double(),
#   `13` = col_double(),
#   `38` = col_double(),
#   `53` = col_double(),
#   `63` = col_double(),
#   `64` = col_double(),
#   `88` = col_double(),
#   `107` = col_double(),
#   `126` = col_double(),
#   `129` = col_double(),
#   `133` = col_double()
# )

# %%
ltr_test_features = read_csv(paste0('../build/simulation/', fold, '/examination_features.csv'))
# Out:
# Parsed with column specification:
# cols(
#   partition = col_character(),
#   `13` = col_double(),
#   `38` = col_double(),
#   `53` = col_double(),
#   `63` = col_double(),
#   `64` = col_double(),
#   `88` = col_double(),
#   `107` = col_double(),
#   `126` = col_double(),
#   `129` = col_double(),
#   `133` = col_double(),
#   qd_id = col_double()
# )

# %%
head(propensity_test_features)
# Out:
#   qid y 13         38         53         63         64         88
# 1 1   1 -1.0517464 -0.8043028 -0.5379134 -0.7348817 -0.8378642 -0.7383881
# 2 1   1 -0.5011712  1.3082802  1.7877163  1.6193548  2.3323488  0.7436748
# 3 1   1  0.5999794  1.3082802  0.8574616  0.6776574  0.4302210  0.7436748
# 4 1   0  0.8752670 -0.8043028 -0.5379134 -0.7348817 -0.7842749 -0.7383881
# 5 1   0 -1.0517464 -0.8043028 -0.5379134 -0.7348817  0.7760532 -0.7383881
# 6 1   0 -1.0517464 -0.8043028 -0.5379134 -0.7348817  0.5640294 -0.7383881
#   107        126        129        133
# 1 -1.2176843 -0.8195302 -0.1129179 -0.01501939
# 2 -1.2176843 -0.3575459 -0.6929039 -0.01501939
# 3 -1.2176843  1.5743887 -0.6706098 -0.01501939
# 4 -1.2176843  0.6084214 -0.6963567 -0.01501939
# 5 -0.5841292 -0.5255402 -0.6954615 -0.01501939
# 6 -1.2176843 -0.5255402 -0.6954615 -0.01501939

# %%
head(ltr_test_features)
# Out:
#   partition 13         38         53         63          64         88
# 1 train      0.8752670  0.2519887 -0.5379134 -0.09281209  0.4462750  0.0417442
# 2 train      0.5999794  0.2519887 -0.5379134 -0.02861219  0.6196983  0.0417442
# 3 train      1.9764176 -0.8043028 -0.5379134 -0.73488173  0.5179472 -0.7383881
# 4 train     -0.5011712  0.2519887 -0.5379134  0.44222946  0.6925879  0.0417442
# 5 train     -1.0517464  0.2519887 -0.5379134  1.03079212  0.7472423  0.0417442
# 6 train      0.5999794  1.3082802 -0.5379134  0.67765735 -0.3119385  0.8218767
#   107         126        129        133           qd_id
# 1 -0.37168315  0.9864086 -0.1828691 -0.0150193933 0
# 2  0.02206703  0.3984285 -0.6789221 -0.0150193933 1
# 3 -0.33572059  1.3223972  0.2067863 -0.0150193933 2
# 4 -0.17473643 -0.6935345  2.0668253  0.0004752088 3
# 5 -0.17473643 -1.2395160  2.0808496 -0.0150193933 4
# 6 -0.12738014  0.2304342 -0.6967830 -0.0150193933 5

# %% [markdown]
# Compute nunique qids

# %%
sim_exp_train_vali_rankings = read_csv(paste0('../build/simulation/', fold, '/sim_exp_train_vali_rankings.csv'))
nqids = sim_exp_train_vali_rankings %>% .$qid %>% n_distinct()
# Out:
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   partition = col_character()
# )
# See spec(...) for full column specifications.

# %%
nqids
# Out:
# [1] 15992

# %%
avg_clicks = c(5, 10, 25, 50)
nqueries = nqids %/% c(100, 10, 2, 1)

# %%
# cf_model$tuning.output$params$
# Out:
# $sample.fraction
# [1] 0.5
#
# $mtry
# [1] 10
#
# $min.node.size
# [1] 5
#
# $honesty.fraction
# [1] 0.5
#
# $honesty.prune.leaves
# [1] TRUE
#
# $alpha
# [1] 0.05
#
# $imbalance.penalty
# [1] 0

# %%
for (avg_click in avg_clicks) {
    for (nq in nqueries) {
        dpath = paste0('../build/simulation/', fold, '/sim_exp_swap_causal_forests_train_clicks_', avg_click, '_', nq, '.csv')
        message('read data from ', dpath)
        data = read_csv(dpath)
        models = vector("list", 9)
        propensity_test_results = vector("list", 9)
        ltr_test_results = vector("list", 9)
        for (i in 2:10) {
            message('sess ', avg_click, ' nsample ', nq, ' train ', i, ' model')
            # slice data
            train_pairs = data %>% filter(treatment_group == i)
            # train outcome model
            Y_model = regression_forest(train_pairs[feature_col], train_pairs$click, tune.parameters = "all")
            Y_pred = predict(Y_model)$predictions
            # train treatment model
            W_model = regression_forest(train_pairs[feature_col], train_pairs$treatment, tune.parameters = "all")
            W_pred = predict(W_model)$predictions
            # train causal model
            cf_model = causal_forest(train_pairs[feature_col], train_pairs$click, train_pairs$treatment, ci.group.size=1,
                                     Y.hat=Y_pred, W.hat=W_pred, tune.parameters = "all")
            # predict tau on test data
            propensity_test_tau_pred = predict(cf_model, propensity_test_features[feature_col])$predictions
            propensity_test_result = propensity_test_features %>% mutate(tau_pred=propensity_test_tau_pred)
            # predict tau on ltr test data
            ltr_test_tau_pred = predict(cf_model, ltr_test_features[feature_col])$predictions
            ltr_test_result = ltr_test_features %>% mutate(tau_pred=ltr_test_tau_pred)
            
            # append results
            idx = i - 1
            models[[idx]] = cf_model
            propensity_test_results[[idx]] = propensity_test_result
            ltr_test_results[[idx]] = ltr_test_result
        }
        propensity_test_results_binded = bind_rows(propensity_test_results, .id='treatment_rank')
        saveto = paste0('../build/simulation/', fold, '/sim_exp_swap_causal_forests_propensity_test_results_', avg_click, '_', nq, '.csv')
        message('save propensity results to ', saveto)
        propensity_test_results_binded %>% write_csv(saveto)
        # ltr results
        ltr_test_results_binded = bind_rows(ltr_test_results, .id='treatment_rank')
        saveto = paste0('../build/simulation/', fold, '/sim_exp_swap_causal_forests_ltr_test_results_', avg_click, '_', nq, '.csv')
        message('save ltr results to ', saveto)
        ltr_test_results_binded %>% write_csv(saveto)
    }
}
# Out:
# read data from ../build/simulation/Fold3/sim_exp_swap_causal_forests_train_clicks_5_159.csv
# Parsed with column specification:
# cols(
#   partition = col_character(),
#   qd_id = col_double(),
#   swapped_rank = col_double(),
#   click = col_double(),
#   treatment = col_double(),
#   true_click_probability = col_double(),
#   true_propensity = col_double(),
#   treatment_group = col_double(),
#   `13` = col_double(),
#   `38` = col_double(),
#   `53` = col_double(),
#   `63` = col_double(),
#   `64` = col_double(),
#   `88` = col_double(),
#   `107` = col_double(),
#   `126` = col_double(),
#   `129` = col_double(),
#   `133` = col_double()
# )
# sess 5 nsample 159 train 2 model
# sess 5 nsample 159 train 3 model
# sess 5 nsample 159 train 4 model
# sess 5 nsample 159 train 5 model
# sess 5 nsample 159 train 6 model
# sess 5 nsample 159 train 7 model
# sess 5 nsample 159 train 8 model
# sess 5 nsample 159 train 9 model
# sess 5 nsample 159 train 10 model
# save propensity results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_propensity_test_results_5_159.csv
# save ltr results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_ltr_test_results_5_159.csv
# read data from ../build/simulation/Fold3/sim_exp_swap_causal_forests_train_clicks_5_1599.csv
# Parsed with column specification:
# cols(
#   partition = col_character(),
#   qd_id = col_double(),
#   swapped_rank = col_double(),
#   click = col_double(),
#   treatment = col_double(),
#   true_click_probability = col_double(),
#   true_propensity = col_double(),
#   treatment_group = col_double(),
#   `13` = col_double(),
#   `38` = col_double(),
#   `53` = col_double(),
#   `63` = col_double(),
#   `64` = col_double(),
#   `88` = col_double(),
#   `107` = col_double(),
#   `126` = col_double(),
#   `129` = col_double(),
#   `133` = col_double()
# )
# sess 5 nsample 1599 train 2 model
# sess 5 nsample 1599 train 3 model
# sess 5 nsample 1599 train 4 model
# sess 5 nsample 1599 train 5 model
# sess 5 nsample 1599 train 6 model
# sess 5 nsample 1599 train 7 model
# sess 5 nsample 1599 train 8 model
# sess 5 nsample 1599 train 9 model
# sess 5 nsample 1599 train 10 model
# save propensity results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_propensity_test_results_5_1599.csv
# save ltr results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_ltr_test_results_5_1599.csv
# read data from ../build/simulation/Fold3/sim_exp_swap_causal_forests_train_clicks_5_7996.csv
# Parsed with column specification:
# cols(
#   partition = col_character(),
#   qd_id = col_double(),
#   swapped_rank = col_double(),
#   click = col_double(),
#   treatment = col_double(),
#   true_click_probability = col_double(),
#   true_propensity = col_double(),
#   treatment_group = col_double(),
#   `13` = col_double(),
#   `38` = col_double(),
#   `53` = col_double(),
#   `63` = col_double(),
#   `64` = col_double(),
#   `88` = col_double(),
#   `107` = col_double(),
#   `126` = col_double(),
#   `129` = col_double(),
#   `133` = col_double()
# )
# sess 5 nsample 7996 train 2 model
# sess 5 nsample 7996 train 3 model
# sess 5 nsample 7996 train 4 model
# sess 5 nsample 7996 train 5 model
# sess 5 nsample 7996 train 6 model
# sess 5 nsample 7996 train 7 model
# sess 5 nsample 7996 train 8 model
# sess 5 nsample 7996 train 9 model
# sess 5 nsample 7996 train 10 model
# save propensity results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_propensity_test_results_5_7996.csv
# save ltr results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_ltr_test_results_5_7996.csv
# read data from ../build/simulation/Fold3/sim_exp_swap_causal_forests_train_clicks_5_15992.csv
# Parsed with column specification:
# cols(
#   partition = col_character(),
#   qd_id = col_double(),
#   swapped_rank = col_double(),
#   click = col_double(),
#   treatment = col_double(),
#   true_click_probability = col_double(),
#   true_propensity = col_double(),
#   treatment_group = col_double(),
#   `13` = col_double(),
#   `38` = col_double(),
#   `53` = col_double(),
#   `63` = col_double(),
#   `64` = col_double(),
#   `88` = col_double(),
#   `107` = col_double(),
#   `126` = col_double(),
#   `129` = col_double(),
#   `133` = col_double()
# )
# sess 5 nsample 15992 train 2 model
# sess 5 nsample 15992 train 3 model
# sess 5 nsample 15992 train 4 model
# sess 5 nsample 15992 train 5 model
# sess 5 nsample 15992 train 6 model
# sess 5 nsample 15992 train 7 model
# sess 5 nsample 15992 train 8 model
# sess 5 nsample 15992 train 9 model
# sess 5 nsample 15992 train 10 model
# save propensity results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_propensity_test_results_5_15992.csv
# save ltr results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_ltr_test_results_5_15992.csv
# read data from ../build/simulation/Fold3/sim_exp_swap_causal_forests_train_clicks_10_159.csv
# Parsed with column specification:
# cols(
#   partition = col_character(),
#   qd_id = col_double(),
#   swapped_rank = col_double(),
#   click = col_double(),
#   treatment = col_double(),
#   true_click_probability = col_double(),
#   true_propensity = col_double(),
#   treatment_group = col_double(),
#   `13` = col_double(),
#   `38` = col_double(),
#   `53` = col_double(),
#   `63` = col_double(),
#   `64` = col_double(),
#   `88` = col_double(),
#   `107` = col_double(),
#   `126` = col_double(),
#   `129` = col_double(),
#   `133` = col_double()
# )
# sess 10 nsample 159 train 2 model
# sess 10 nsample 159 train 3 model
# sess 10 nsample 159 train 4 model
# sess 10 nsample 159 train 5 model
# sess 10 nsample 159 train 6 model
# sess 10 nsample 159 train 7 model
# sess 10 nsample 159 train 8 model
# sess 10 nsample 159 train 9 model
# sess 10 nsample 159 train 10 model
# save propensity results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_propensity_test_results_10_159.csv
# save ltr results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_ltr_test_results_10_159.csv
# read data from ../build/simulation/Fold3/sim_exp_swap_causal_forests_train_clicks_10_1599.csv
# Parsed with column specification:
# cols(
#   partition = col_character(),
#   qd_id = col_double(),
#   swapped_rank = col_double(),
#   click = col_double(),
#   treatment = col_double(),
#   true_click_probability = col_double(),
#   true_propensity = col_double(),
#   treatment_group = col_double(),
#   `13` = col_double(),
#   `38` = col_double(),
#   `53` = col_double(),
#   `63` = col_double(),
#   `64` = col_double(),
#   `88` = col_double(),
#   `107` = col_double(),
#   `126` = col_double(),
#   `129` = col_double(),
#   `133` = col_double()
# )
# sess 10 nsample 1599 train 2 model
# sess 10 nsample 1599 train 3 model
# sess 10 nsample 1599 train 4 model
# sess 10 nsample 1599 train 5 model
# sess 10 nsample 1599 train 6 model
# sess 10 nsample 1599 train 7 model
# sess 10 nsample 1599 train 8 model
# sess 10 nsample 1599 train 9 model
# sess 10 nsample 1599 train 10 model
# save propensity results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_propensity_test_results_10_1599.csv
# save ltr results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_ltr_test_results_10_1599.csv
# read data from ../build/simulation/Fold3/sim_exp_swap_causal_forests_train_clicks_10_7996.csv
# Parsed with column specification:
# cols(
#   partition = col_character(),
#   qd_id = col_double(),
#   swapped_rank = col_double(),
#   click = col_double(),
#   treatment = col_double(),
#   true_click_probability = col_double(),
#   true_propensity = col_double(),
#   treatment_group = col_double(),
#   `13` = col_double(),
#   `38` = col_double(),
#   `53` = col_double(),
#   `63` = col_double(),
#   `64` = col_double(),
#   `88` = col_double(),
#   `107` = col_double(),
#   `126` = col_double(),
#   `129` = col_double(),
#   `133` = col_double()
# )
# sess 10 nsample 7996 train 2 model
# sess 10 nsample 7996 train 3 model
# sess 10 nsample 7996 train 4 model
# sess 10 nsample 7996 train 5 model
# sess 10 nsample 7996 train 6 model
# sess 10 nsample 7996 train 7 model
# sess 10 nsample 7996 train 8 model
# sess 10 nsample 7996 train 9 model
# sess 10 nsample 7996 train 10 model
# save propensity results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_propensity_test_results_10_7996.csv
# save ltr results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_ltr_test_results_10_7996.csv
# read data from ../build/simulation/Fold3/sim_exp_swap_causal_forests_train_clicks_10_15992.csv
# Parsed with column specification:
# cols(
#   partition = col_character(),
#   qd_id = col_double(),
#   swapped_rank = col_double(),
#   click = col_double(),
#   treatment = col_double(),
#   true_click_probability = col_double(),
#   true_propensity = col_double(),
#   treatment_group = col_double(),
#   `13` = col_double(),
#   `38` = col_double(),
#   `53` = col_double(),
#   `63` = col_double(),
#   `64` = col_double(),
#   `88` = col_double(),
#   `107` = col_double(),
#   `126` = col_double(),
#   `129` = col_double(),
#   `133` = col_double()
# )
# sess 10 nsample 15992 train 2 model
# sess 10 nsample 15992 train 3 model
# sess 10 nsample 15992 train 4 model
# sess 10 nsample 15992 train 5 model
# sess 10 nsample 15992 train 6 model
# sess 10 nsample 15992 train 7 model
# sess 10 nsample 15992 train 8 model
# sess 10 nsample 15992 train 9 model
# sess 10 nsample 15992 train 10 model
# save propensity results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_propensity_test_results_10_15992.csv
# save ltr results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_ltr_test_results_10_15992.csv
# read data from ../build/simulation/Fold3/sim_exp_swap_causal_forests_train_clicks_25_159.csv
# Parsed with column specification:
# cols(
#   partition = col_character(),
#   qd_id = col_double(),
#   swapped_rank = col_double(),
#   click = col_double(),
#   treatment = col_double(),
#   true_click_probability = col_double(),
#   true_propensity = col_double(),
#   treatment_group = col_double(),
#   `13` = col_double(),
#   `38` = col_double(),
#   `53` = col_double(),
#   `63` = col_double(),
#   `64` = col_double(),
#   `88` = col_double(),
#   `107` = col_double(),
#   `126` = col_double(),
#   `129` = col_double(),
#   `133` = col_double()
# )
# sess 25 nsample 159 train 2 model
# sess 25 nsample 159 train 3 model
# sess 25 nsample 159 train 4 model
# sess 25 nsample 159 train 5 model
# sess 25 nsample 159 train 6 model
# sess 25 nsample 159 train 7 model
# sess 25 nsample 159 train 8 model
# sess 25 nsample 159 train 9 model
# sess 25 nsample 159 train 10 model
# save propensity results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_propensity_test_results_25_159.csv
# save ltr results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_ltr_test_results_25_159.csv
# read data from ../build/simulation/Fold3/sim_exp_swap_causal_forests_train_clicks_25_1599.csv
# Parsed with column specification:
# cols(
#   partition = col_character(),
#   qd_id = col_double(),
#   swapped_rank = col_double(),
#   click = col_double(),
#   treatment = col_double(),
#   true_click_probability = col_double(),
#   true_propensity = col_double(),
#   treatment_group = col_double(),
#   `13` = col_double(),
#   `38` = col_double(),
#   `53` = col_double(),
#   `63` = col_double(),
#   `64` = col_double(),
#   `88` = col_double(),
#   `107` = col_double(),
#   `126` = col_double(),
#   `129` = col_double(),
#   `133` = col_double()
# )
# sess 25 nsample 1599 train 2 model
# sess 25 nsample 1599 train 3 model
# sess 25 nsample 1599 train 4 model
# sess 25 nsample 1599 train 5 model
# sess 25 nsample 1599 train 6 model
# sess 25 nsample 1599 train 7 model
# sess 25 nsample 1599 train 8 model
# sess 25 nsample 1599 train 9 model
# sess 25 nsample 1599 train 10 model
# save propensity results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_propensity_test_results_25_1599.csv
# save ltr results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_ltr_test_results_25_1599.csv
# read data from ../build/simulation/Fold3/sim_exp_swap_causal_forests_train_clicks_25_7996.csv
# Parsed with column specification:
# cols(
#   partition = col_character(),
#   qd_id = col_double(),
#   swapped_rank = col_double(),
#   click = col_double(),
#   treatment = col_double(),
#   true_click_probability = col_double(),
#   true_propensity = col_double(),
#   treatment_group = col_double(),
#   `13` = col_double(),
#   `38` = col_double(),
#   `53` = col_double(),
#   `63` = col_double(),
#   `64` = col_double(),
#   `88` = col_double(),
#   `107` = col_double(),
#   `126` = col_double(),
#   `129` = col_double(),
#   `133` = col_double()
# )
# sess 25 nsample 7996 train 2 model
# sess 25 nsample 7996 train 3 model
# sess 25 nsample 7996 train 4 model
# sess 25 nsample 7996 train 5 model
# sess 25 nsample 7996 train 6 model
# sess 25 nsample 7996 train 7 model
# sess 25 nsample 7996 train 8 model
# sess 25 nsample 7996 train 9 model
# sess 25 nsample 7996 train 10 model
# save propensity results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_propensity_test_results_25_7996.csv
# save ltr results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_ltr_test_results_25_7996.csv
# read data from ../build/simulation/Fold3/sim_exp_swap_causal_forests_train_clicks_25_15992.csv
# Parsed with column specification:
# cols(
#   partition = col_character(),
#   qd_id = col_double(),
#   swapped_rank = col_double(),
#   click = col_double(),
#   treatment = col_double(),
#   true_click_probability = col_double(),
#   true_propensity = col_double(),
#   treatment_group = col_double(),
#   `13` = col_double(),
#   `38` = col_double(),
#   `53` = col_double(),
#   `63` = col_double(),
#   `64` = col_double(),
#   `88` = col_double(),
#   `107` = col_double(),
#   `126` = col_double(),
#   `129` = col_double(),
#   `133` = col_double()
# )
# sess 25 nsample 15992 train 2 model
# sess 25 nsample 15992 train 3 model
# sess 25 nsample 15992 train 4 model
# sess 25 nsample 15992 train 5 model
# sess 25 nsample 15992 train 6 model
# sess 25 nsample 15992 train 7 model
# sess 25 nsample 15992 train 8 model
# sess 25 nsample 15992 train 9 model
# sess 25 nsample 15992 train 10 model
# save propensity results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_propensity_test_results_25_15992.csv
# save ltr results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_ltr_test_results_25_15992.csv
# read data from ../build/simulation/Fold3/sim_exp_swap_causal_forests_train_clicks_50_159.csv
# Parsed with column specification:
# cols(
#   partition = col_character(),
#   qd_id = col_double(),
#   swapped_rank = col_double(),
#   click = col_double(),
#   treatment = col_double(),
#   true_click_probability = col_double(),
#   true_propensity = col_double(),
#   treatment_group = col_double(),
#   `13` = col_double(),
#   `38` = col_double(),
#   `53` = col_double(),
#   `63` = col_double(),
#   `64` = col_double(),
#   `88` = col_double(),
#   `107` = col_double(),
#   `126` = col_double(),
#   `129` = col_double(),
#   `133` = col_double()
# )
# sess 50 nsample 159 train 2 model
# sess 50 nsample 159 train 3 model
# sess 50 nsample 159 train 4 model
# sess 50 nsample 159 train 5 model
# sess 50 nsample 159 train 6 model
# sess 50 nsample 159 train 7 model
# sess 50 nsample 159 train 8 model
# sess 50 nsample 159 train 9 model
# sess 50 nsample 159 train 10 model
# save propensity results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_propensity_test_results_50_159.csv
# save ltr results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_ltr_test_results_50_159.csv
# read data from ../build/simulation/Fold3/sim_exp_swap_causal_forests_train_clicks_50_1599.csv
# Parsed with column specification:
# cols(
#   partition = col_character(),
#   qd_id = col_double(),
#   swapped_rank = col_double(),
#   click = col_double(),
#   treatment = col_double(),
#   true_click_probability = col_double(),
#   true_propensity = col_double(),
#   treatment_group = col_double(),
#   `13` = col_double(),
#   `38` = col_double(),
#   `53` = col_double(),
#   `63` = col_double(),
#   `64` = col_double(),
#   `88` = col_double(),
#   `107` = col_double(),
#   `126` = col_double(),
#   `129` = col_double(),
#   `133` = col_double()
# )
# sess 50 nsample 1599 train 2 model
# sess 50 nsample 1599 train 3 model
# sess 50 nsample 1599 train 4 model
# sess 50 nsample 1599 train 5 model
# sess 50 nsample 1599 train 6 model
# sess 50 nsample 1599 train 7 model
# sess 50 nsample 1599 train 8 model
# sess 50 nsample 1599 train 9 model
# sess 50 nsample 1599 train 10 model
# save propensity results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_propensity_test_results_50_1599.csv
# save ltr results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_ltr_test_results_50_1599.csv
# read data from ../build/simulation/Fold3/sim_exp_swap_causal_forests_train_clicks_50_7996.csv
# Parsed with column specification:
# cols(
#   partition = col_character(),
#   qd_id = col_double(),
#   swapped_rank = col_double(),
#   click = col_double(),
#   treatment = col_double(),
#   true_click_probability = col_double(),
#   true_propensity = col_double(),
#   treatment_group = col_double(),
#   `13` = col_double(),
#   `38` = col_double(),
#   `53` = col_double(),
#   `63` = col_double(),
#   `64` = col_double(),
#   `88` = col_double(),
#   `107` = col_double(),
#   `126` = col_double(),
#   `129` = col_double(),
#   `133` = col_double()
# )
# sess 50 nsample 7996 train 2 model
# sess 50 nsample 7996 train 3 model
# sess 50 nsample 7996 train 4 model
# sess 50 nsample 7996 train 5 model
# sess 50 nsample 7996 train 6 model
# sess 50 nsample 7996 train 7 model
# sess 50 nsample 7996 train 8 model
# sess 50 nsample 7996 train 9 model
# sess 50 nsample 7996 train 10 model
# save propensity results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_propensity_test_results_50_7996.csv
# save ltr results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_ltr_test_results_50_7996.csv
# read data from ../build/simulation/Fold3/sim_exp_swap_causal_forests_train_clicks_50_15992.csv
# Parsed with column specification:
# cols(
#   partition = col_character(),
#   qd_id = col_double(),
#   swapped_rank = col_double(),
#   click = col_double(),
#   treatment = col_double(),
#   true_click_probability = col_double(),
#   true_propensity = col_double(),
#   treatment_group = col_double(),
#   `13` = col_double(),
#   `38` = col_double(),
#   `53` = col_double(),
#   `63` = col_double(),
#   `64` = col_double(),
#   `88` = col_double(),
#   `107` = col_double(),
#   `126` = col_double(),
#   `129` = col_double(),
#   `133` = col_double()
# )
# sess 50 nsample 15992 train 2 model
# sess 50 nsample 15992 train 3 model
# sess 50 nsample 15992 train 4 model
# sess 50 nsample 15992 train 5 model
# sess 50 nsample 15992 train 6 model
# sess 50 nsample 15992 train 7 model
# sess 50 nsample 15992 train 8 model
# sess 50 nsample 15992 train 9 model
# sess 50 nsample 15992 train 10 model
# save propensity results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_propensity_test_results_50_15992.csv
# save ltr results to ../build/simulation/Fold3/sim_exp_swap_causal_forests_ltr_test_results_50_15992.csv
